# %% [markdown]
# ## Create an empty DataFrame

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.appName('sample1').master('local').getOrCreate()

# %%
df = spark.createDataFrame([], "id int, name String")

# %% [markdown]
# ## Convert RDD to DataFrame

# %%
rdd = spark.sparkContext.parallelize([(1, 'Alice'),(2, 'Bob')])

# %%
columns = ['id','name']
df = rdd.toDF(schema=columns)
df.show()
# Out:
# 25/02/07 16:02:59 INFO SparkContext: Starting job: runJob at PythonRDD.scala:166
# 25/02/07 16:02:59 INFO DAGScheduler: Got job 4 (runJob at PythonRDD.scala:166) with 1 output partitions
# 25/02/07 16:02:59 INFO DAGScheduler: Final stage: ResultStage 4 (runJob at PythonRDD.scala:166)
# 25/02/07 16:02:59 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 16:02:59 INFO DAGScheduler: Missing parents: List()
# 25/02/07 16:02:59 INFO DAGScheduler: Submitting ResultStage 4 (PythonRDD[23] at RDD at PythonRDD.scala:53), which has no missing parents
# 25/02/07 16:02:59 INFO MemoryStore: Block broadcast_4 stored as values in memory (estimated size 6.7 KiB, free 6.2 GiB)
# 25/02/07 16:02:59 INFO MemoryStore: Block broadcast_4_piece0 stored as bytes in memory (estimated size 4.2 KiB, free 6.2 GiB)
# 25/02/07 16:02:59 INFO BlockManagerInfo: Added broadcast_4_piece0 in memory on 1cdc7ec21abb:36743 (size: 4.2 KiB, free: 6.2 GiB)
# 25/02/07 16:02:59 INFO SparkContext: Created broadcast 4 from broadcast at DAGScheduler.scala:1570
# 25/02/07 16:02:59 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 4 (PythonRDD[23] at RDD at PythonRDD.scala:53) (first 15 tasks are for partitions Vector(0))
# 25/02/07 16:02:59 INFO TaskSchedulerImpl: Adding task set 4.0 with 1 tasks resource profile 0
# 25/02/07 16:02:59 INFO TaskSetManager: Starting task 0.0 in stage 4.0 (TID 4) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4481 bytes) taskResourceAssignments Map()
# 25/02/07 16:02:59 INFO Executor: Running task 0.0 in stage 4.0 (TID 4)
# 25/02/07 16:02:59 INFO PythonRunner: Times: total = 77, boot = 5, init = 71, finish = 1
# 25/02/07 16:02:59 INFO Executor: Finished task 0.0 in stage 4.0 (TID 4). 1329 bytes result sent to driver
# 25/02/07 16:02:59 INFO TaskSetManager: Finished task 0.0 in stage 4.0 (TID 4) in 87 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 16:02:59 INFO TaskSchedulerImpl: Removed TaskSet 4.0, whose tasks have all completed, from pool
# 25/02/07 16:02:59 INFO DAGScheduler: ResultStage 4 (runJob at PythonRDD.scala:166) finished in 0.098 s
# 25/02/07 16:02:59 INFO DAGScheduler: Job 4 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 16:02:59 INFO TaskSchedulerImpl: Killing all running tasks in stage 4: Stage finished
# 25/02/07 16:02:59 INFO DAGScheduler: Job 4 finished: runJob at PythonRDD.scala:166, took 0.101550 s
# 25/02/07 16:03:00 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 25/02/07 16:03:00 INFO DAGScheduler: Got job 5 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/02/07 16:03:00 INFO DAGScheduler: Final stage: ResultStage 5 (showString at NativeMethodAccessorImpl.java:0)
# 25/02/07 16:03:00 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 16:03:00 INFO DAGScheduler: Missing parents: List()
# 25/02/07 16:03:00 INFO DAGScheduler: Submitting ResultStage 5 (MapPartitionsRDD[29] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/02/07 16:03:00 INFO MemoryStore: Block broadcast_5 stored as values in memory (estimated size 14.9 KiB, free 6.2 GiB)
# 25/02/07 16:03:00 INFO MemoryStore: Block broadcast_5_piece0 stored as bytes in memory (estimated size 8.0 KiB, free 6.2 GiB)
# 25/02/07 16:03:00 INFO BlockManagerInfo: Added broadcast_5_piece0 in memory on 1cdc7ec21abb:36743 (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:03:00 INFO SparkContext: Created broadcast 5 from broadcast at DAGScheduler.scala:1570
# 25/02/07 16:03:00 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 5 (MapPartitionsRDD[29] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 16:03:00 INFO TaskSchedulerImpl: Adding task set 5.0 with 1 tasks resource profile 0
# 25/02/07 16:03:00 INFO TaskSetManager: Starting task 0.0 in stage 5.0 (TID 5) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4481 bytes) taskResourceAssignments Map()
# 25/02/07 16:03:00 INFO Executor: Running task 0.0 in stage 5.0 (TID 5)
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+
# 25/02/07 16:03:00 INFO PythonRunner: Times: total = 90, boot = 4, init = 86, finish = 0
# 25/02/07 16:03:00 INFO Executor: Finished task 0.0 in stage 5.0 (TID 5). 1850 bytes result sent to driver
# 25/02/07 16:03:00 INFO TaskSetManager: Finished task 0.0 in stage 5.0 (TID 5) in 101 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 16:03:00 INFO TaskSchedulerImpl: Removed TaskSet 5.0, whose tasks have all completed, from pool
# 25/02/07 16:03:00 INFO DAGScheduler: ResultStage 5 (showString at NativeMethodAccessorImpl.java:0) finished in 0.110 s
# 25/02/07 16:03:00 INFO DAGScheduler: Job 5 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 16:03:00 INFO TaskSchedulerImpl: Killing all running tasks in stage 5: Stage finished
# 25/02/07 16:03:00 INFO DAGScheduler: Job 5 finished: showString at NativeMethodAccessorImpl.java:0, took 0.115673 s

# %% [markdown]
# ## Convert DataFrame to Pandas

# %%
df.toPandas()

# %% [markdown]
# ## StructType & StructField

# %%
# These classes are used to define the schema for DataFrames.
from pyspark.sql.types import IntegerType, StringType
schema = StructType([
    StructField(name='id', dataType=IntegerType()),
    StructField(name='name', dataType=StringType())
])
df = spark.createDataFrame([(1, "Alice"), (2, "Bob")], schema)
df.show()

# %% [markdown]
# ## Column Class
# The Column class represents a column in a DataFrame and is used for performing operations.

# %%
df.columns
# Out:
# ['id', 'name']

# %% [markdown]
# ## Select

# %%
df.select('id', 'name').show()
# Out:
# 25/02/07 15:56:00 INFO CodeGenerator: Code generated in 129.527671 ms
# 25/02/07 15:56:00 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 25/02/07 15:56:00 INFO DAGScheduler: Got job 0 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/02/07 15:56:00 INFO DAGScheduler: Final stage: ResultStage 0 (showString at NativeMethodAccessorImpl.java:0)
# 25/02/07 15:56:00 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 15:56:00 INFO DAGScheduler: Missing parents: List()
# 25/02/07 15:56:00 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/02/07 15:56:00 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 12.6 KiB, free 6.2 GiB)
# 25/02/07 15:56:00 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 6.6 KiB, free 6.2 GiB)
# 25/02/07 15:56:00 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 1cdc7ec21abb:36743 (size: 6.6 KiB, free: 6.2 GiB)
# 25/02/07 15:56:00 INFO SparkContext: Created broadcast 0 from broadcast at DAGScheduler.scala:1570
# 25/02/07 15:56:00 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 15:56:00 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 25/02/07 15:56:00 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4433 bytes) taskResourceAssignments Map()
# 25/02/07 15:56:00 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# [Stage 0:>                                                          (0 + 1) / 1]
# +---+----+
# | id|name|
# +---+----+
# +---+----+
# 25/02/07 15:56:01 INFO PythonRunner: Times: total = 707, boot = 630, init = 77, finish = 0
# 25/02/07 15:56:01 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1789 bytes result sent to driver
# 25/02/07 15:56:01 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 1087 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 15:56:01 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 25/02/07 15:56:01 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 35311
# 25/02/07 15:56:02 INFO DAGScheduler: ResultStage 0 (showString at NativeMethodAccessorImpl.java:0) finished in 1.271 s
# 25/02/07 15:56:02 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 15:56:02 INFO TaskSchedulerImpl: Killing all running tasks in stage 0: Stage finished
# 25/02/07 15:56:02 INFO DAGScheduler: Job 0 finished: showString at NativeMethodAccessorImpl.java:0, took 1.327157 s
# 25/02/07 15:56:02 INFO BlockManagerInfo: Removed broadcast_0_piece0 on 1cdc7ec21abb:36743 in memory (size: 6.6 KiB, free: 6.2 GiB)

# %% [markdown]
# ## collect()
# collect() returns all the rows as a list of Row objects.

# %%
rows = df.collect()
print(rows)
# Out:
# [Row(id=1, name='Alice'), Row(id=2, name='Bob')]
# 25/02/07 15:56:49 INFO CodeGenerator: Code generated in 11.782167 ms
# 25/02/07 15:56:49 INFO SparkContext: Starting job: collect at /tmp/ipykernel_2986/1121679628.py:1
# 25/02/07 15:56:49 INFO DAGScheduler: Got job 3 (collect at /tmp/ipykernel_2986/1121679628.py:1) with 1 output partitions
# 25/02/07 15:56:49 INFO DAGScheduler: Final stage: ResultStage 3 (collect at /tmp/ipykernel_2986/1121679628.py:1)
# 25/02/07 15:56:49 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 15:56:49 INFO DAGScheduler: Missing parents: List()
# 25/02/07 15:56:49 INFO DAGScheduler: Submitting ResultStage 3 (MapPartitionsRDD[16] at collect at /tmp/ipykernel_2986/1121679628.py:1), which has no missing parents
# 25/02/07 15:56:49 INFO MemoryStore: Block broadcast_3 stored as values in memory (estimated size 14.7 KiB, free 6.2 GiB)
# 25/02/07 15:56:49 INFO MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 7.8 KiB, free 6.2 GiB)
# 25/02/07 15:56:49 INFO BlockManagerInfo: Added broadcast_3_piece0 in memory on 1cdc7ec21abb:36743 (size: 7.8 KiB, free: 6.2 GiB)
# 25/02/07 15:56:49 INFO SparkContext: Created broadcast 3 from broadcast at DAGScheduler.scala:1570
# 25/02/07 15:56:49 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 3 (MapPartitionsRDD[16] at collect at /tmp/ipykernel_2986/1121679628.py:1) (first 15 tasks are for partitions Vector(0))
# 25/02/07 15:56:49 INFO TaskSchedulerImpl: Adding task set 3.0 with 1 tasks resource profile 0
# 25/02/07 15:56:49 INFO TaskSetManager: Starting task 0.0 in stage 3.0 (TID 3) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4481 bytes) taskResourceAssignments Map()
# 25/02/07 15:56:49 INFO Executor: Running task 0.0 in stage 3.0 (TID 3)
# 25/02/07 15:56:49 INFO PythonRunner: Times: total = 65, boot = -9045, init = 9110, finish = 0
# 25/02/07 15:56:49 INFO Executor: Finished task 0.0 in stage 3.0 (TID 3). 1877 bytes result sent to driver
# 25/02/07 15:56:49 INFO TaskSetManager: Finished task 0.0 in stage 3.0 (TID 3) in 76 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 15:56:49 INFO TaskSchedulerImpl: Removed TaskSet 3.0, whose tasks have all completed, from pool
# 25/02/07 15:56:49 INFO DAGScheduler: ResultStage 3 (collect at /tmp/ipykernel_2986/1121679628.py:1) finished in 0.087 s
# 25/02/07 15:56:49 INFO DAGScheduler: Job 3 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 15:56:49 INFO TaskSchedulerImpl: Killing all running tasks in stage 3: Stage finished
# 25/02/07 15:56:49 INFO DAGScheduler: Job 3 finished: collect at /tmp/ipykernel_2986/1121679628.py:1, took 0.093491 s

# %% [markdown]
# # withColumn()
# This method is used to add or modify a column.

# %%
df_b = df.withColumn('surname',F.lit('García'))

# %%
df_b.show()
# Out:
# +---+-----+-------+
# | id| name|surname|
# +---+-----+-------+
# |  1|Alice| García|
# |  2|  Bob| García|
# +---+-----+-------+
# 25/02/07 16:03:15 INFO CodeGenerator: Code generated in 13.745858 ms
# 25/02/07 16:03:15 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 25/02/07 16:03:15 INFO DAGScheduler: Got job 6 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/02/07 16:03:15 INFO DAGScheduler: Final stage: ResultStage 6 (showString at NativeMethodAccessorImpl.java:0)
# 25/02/07 16:03:15 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 16:03:15 INFO DAGScheduler: Missing parents: List()
# 25/02/07 16:03:15 INFO DAGScheduler: Submitting ResultStage 6 (MapPartitionsRDD[31] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/02/07 16:03:15 INFO MemoryStore: Block broadcast_6 stored as values in memory (estimated size 15.1 KiB, free 6.2 GiB)
# 25/02/07 16:03:15 INFO MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 8.0 KiB, free 6.2 GiB)
# 25/02/07 16:03:15 INFO BlockManagerInfo: Added broadcast_6_piece0 in memory on 1cdc7ec21abb:36743 (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:03:15 INFO SparkContext: Created broadcast 6 from broadcast at DAGScheduler.scala:1570
# 25/02/07 16:03:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 6 (MapPartitionsRDD[31] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 16:03:15 INFO TaskSchedulerImpl: Adding task set 6.0 with 1 tasks resource profile 0
# 25/02/07 16:03:15 INFO TaskSetManager: Starting task 0.0 in stage 6.0 (TID 6) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4481 bytes) taskResourceAssignments Map()
# 25/02/07 16:03:15 INFO Executor: Running task 0.0 in stage 6.0 (TID 6)
# 25/02/07 16:03:15 INFO PythonRunner: Times: total = 65, boot = -15478, init = 15543, finish = 0
# 25/02/07 16:03:15 INFO Executor: Finished task 0.0 in stage 6.0 (TID 6). 1873 bytes result sent to driver
# 25/02/07 16:03:15 INFO TaskSetManager: Finished task 0.0 in stage 6.0 (TID 6) in 74 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 16:03:15 INFO TaskSchedulerImpl: Removed TaskSet 6.0, whose tasks have all completed, from pool
# 25/02/07 16:03:15 INFO DAGScheduler: ResultStage 6 (showString at NativeMethodAccessorImpl.java:0) finished in 0.084 s
# 25/02/07 16:03:15 INFO DAGScheduler: Job 6 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 16:03:15 INFO TaskSchedulerImpl: Killing all running tasks in stage 6: Stage finished
# 25/02/07 16:03:15 INFO DAGScheduler: Job 6 finished: showString at NativeMethodAccessorImpl.java:0, took 0.089519 s
# 25/02/07 16:03:15 INFO CodeGenerator: Code generated in 11.295984 ms

# %% [markdown]
# ## withColumnRenamed()
# Renames an existing column in the DataFrame.

# %%
df_renamed = df_b.withColumnRenamed('surname', 'apellidos')

# %%
df_renamed.show()
# Out:
# +---+-----+---------+
# | id| name|apellidos|
# +---+-----+---------+
# |  1|Alice|   García|
# |  2|  Bob|   García|
# +---+-----+---------+
# 25/02/07 16:05:42 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 25/02/07 16:05:42 INFO DAGScheduler: Got job 9 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 25/02/07 16:05:42 INFO DAGScheduler: Final stage: ResultStage 9 (showString at NativeMethodAccessorImpl.java:0)
# 25/02/07 16:05:42 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 16:05:42 INFO DAGScheduler: Missing parents: List()
# 25/02/07 16:05:42 INFO DAGScheduler: Submitting ResultStage 9 (MapPartitionsRDD[37] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 25/02/07 16:05:42 INFO MemoryStore: Block broadcast_9 stored as values in memory (estimated size 15.1 KiB, free 6.2 GiB)
# 25/02/07 16:05:42 INFO MemoryStore: Block broadcast_9_piece0 stored as bytes in memory (estimated size 8.0 KiB, free 6.2 GiB)
# 25/02/07 16:05:42 INFO BlockManagerInfo: Added broadcast_9_piece0 in memory on 1cdc7ec21abb:36743 (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:05:42 INFO SparkContext: Created broadcast 9 from broadcast at DAGScheduler.scala:1570
# 25/02/07 16:05:42 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 9 (MapPartitionsRDD[37] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 16:05:42 INFO TaskSchedulerImpl: Adding task set 9.0 with 1 tasks resource profile 0
# 25/02/07 16:05:42 INFO TaskSetManager: Starting task 0.0 in stage 9.0 (TID 9) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4481 bytes) taskResourceAssignments Map()
# 25/02/07 16:05:42 INFO Executor: Running task 0.0 in stage 9.0 (TID 9)
# 25/02/07 16:05:42 INFO PythonRunner: Times: total = 90, boot = -30692, init = 30782, finish = 0
# 25/02/07 16:05:42 INFO Executor: Finished task 0.0 in stage 9.0 (TID 9). 1873 bytes result sent to driver
# 25/02/07 16:05:42 INFO TaskSetManager: Finished task 0.0 in stage 9.0 (TID 9) in 98 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 16:05:42 INFO TaskSchedulerImpl: Removed TaskSet 9.0, whose tasks have all completed, from pool
# 25/02/07 16:05:42 INFO DAGScheduler: ResultStage 9 (showString at NativeMethodAccessorImpl.java:0) finished in 0.108 s
# 25/02/07 16:05:42 INFO DAGScheduler: Job 9 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 16:05:42 INFO TaskSchedulerImpl: Killing all running tasks in stage 9: Stage finished
# 25/02/07 16:05:42 INFO DAGScheduler: Job 9 finished: showString at NativeMethodAccessorImpl.java:0, took 0.114287 s
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_7_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_8_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_4_piece0 on 1cdc7ec21abb:36743 in memory (size: 4.2 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_2_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_9_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_6_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_3_piece0 on 1cdc7ec21abb:36743 in memory (size: 7.8 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_5_piece0 on 1cdc7ec21abb:36743 in memory (size: 8.0 KiB, free: 6.2 GiB)
# 25/02/07 16:25:46 INFO BlockManagerInfo: Removed broadcast_1_piece0 on 1cdc7ec21abb:36743 in memory (size: 4.2 KiB, free: 6.2 GiB)
# 25/02/07 16:58:28 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 495365 ms exceeds timeout 120000 ms
# 25/02/07 16:58:28 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:28 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:28 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:28 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:32 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:32 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:32 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:32 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:32 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:42 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:42 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:42 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:42 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:42 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:58:52 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:58:52 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:58:52 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:52 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:58:52 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 16:59:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 16:59:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 16:59:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 16:59:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:00:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:00:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:00:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:00:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:01:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:01:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:01:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:01:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:02:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:02:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:02:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:02:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:03:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:03:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:03:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:03:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:04:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:04:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:04:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:04:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:05:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:05:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:05:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:05:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:06:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:06:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:06:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:06:53 INFO BlockManager: Reporting 0 blocks to the master.

# %% [markdown]
# ## where() & filter()
# Both methods are used to filter rows based on conditions.

# %%
df.filter(df.name=='Bob').show()

# %%
df.where(df.id > 1).show()

# %% [markdown]
# ## drop() & dropDuplicates()
# Used to drop a column or remove duplicate rows.

# %%
df_renamed_dropped = df_renamed.drop('apellidos')
df_renamed_dropped.show()

# %%
from pyspark.sql import Row
df_with_duplicates = spark.createDataFrame([
    Row(name='Alice', age=5, height=80),
    Row(name='Alice', age=5, height=80),
    Row(name='Alice', age=10, height=80)
])
# Drop based on all columns
df_without_duplicates = df_with_duplicates.drop_duplicates()
df_without_duplicates.show()

# Drop based on specific column
df_without_duplicates = df_with_duplicates.drop_duplicates(subset=['age'])
# Out:
# 25/02/07 17:21:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:03 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:03 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:03 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:03 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:03 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:13 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:13 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:13 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:13 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:13 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:23 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:23 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:23 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:23 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:23 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:33 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:33 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:33 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:33 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:33 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:43 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:43 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:43 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:43 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:43 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:21:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:21:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:21:53 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:21:53 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:21:53 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:53 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:21:53 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:03 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:03 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:03 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:03 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:03 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:13 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:13 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:13 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:13 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:13 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:23 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:23 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:23 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:23 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:23 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:33 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:33 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:33 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:33 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:33 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:43 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:43 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:43 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:43 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:43 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:22:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:22:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:22:53 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:22:53 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:22:53 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:53 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:22:53 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:03 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:03 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:03 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:03 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:03 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:13 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:13 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:13 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:13 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:13 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:23 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:23 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:23 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:23 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:23 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:33 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:33 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:33 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:33 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:33 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:43 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:43 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:43 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:43 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:43 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:23:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:23:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:23:53 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:23:53 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:23:53 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:53 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:23:53 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:03 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:03 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:03 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:03 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:03 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:13 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:13 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:13 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:13 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:13 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:23 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:23 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:23 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:23 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:23 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:33 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:33 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:33 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:33 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:33 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:43 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:43 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:43 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:43 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:43 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:24:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:24:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:24:53 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:24:53 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:24:53 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:53 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:24:53 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:25:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:25:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:25:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:25:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:25:03 INFO BlockManager: Reporting 8 blocks to the master.
# 25/02/07 17:25:03 INFO BlockManagerInfo: Updated broadcast_18_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)
# 25/02/07 17:25:03 INFO BlockManagerInfo: Updated broadcast_17_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:25:03 INFO BlockManagerInfo: Updated broadcast_19_piece0 in memory on 1cdc7ec21abb:36743 (current size: 11.7 KiB, original size: 11.7 KiB, free: 6.2 GiB)
# 25/02/07 17:25:03 INFO BlockManagerInfo: Updated broadcast_20_piece0 in memory on 1cdc7ec21abb:36743 (current size: 17.8 KiB, original size: 17.8 KiB, free: 6.2 GiB)

# %%
spark.se

# %% [markdown]
# # orderBy() and sort()

# %%
data = [("Alice", 30),("Manu", 37),("Charlie", 51)]
df_sort = spark.createDataFrame(data, ["name", "age"])
df_sort.sort('age').show()


df_order_by = spark.createDataFrame(data, ["name", "age"])
df_order_by.orderBy("age", ascending=False).show()
# Out:
# 25/02/07 17:36:28 INFO SparkContext: Starting job: showString at <unknown>:0
# 25/02/07 17:36:28 INFO DAGScheduler: Got job 29 (showString at <unknown>:0) with 1 output partitions
# 25/02/07 17:36:28 INFO DAGScheduler: Final stage: ResultStage 31 (showString at <unknown>:0)
# 25/02/07 17:36:28 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 17:36:28 INFO DAGScheduler: Missing parents: List()
# 25/02/07 17:36:28 INFO DAGScheduler: Submitting ResultStage 31 (MapPartitionsRDD[182] at showString at <unknown>:0), which has no missing parents
# 25/02/07 17:36:28 INFO MemoryStore: Block broadcast_29 stored as values in memory (estimated size 14.7 KiB, free 6.2 GiB)
# 25/02/07 17:36:28 INFO MemoryStore: Block broadcast_29_piece0 stored as bytes in memory (estimated size 7.5 KiB, free 6.2 GiB)
# 25/02/07 17:36:28 INFO BlockManagerInfo: Added broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:28 INFO SparkContext: Created broadcast 29 from broadcast at DAGScheduler.scala:1570
# 25/02/07 17:36:28 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 31 (MapPartitionsRDD[182] at showString at <unknown>:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Adding task set 31.0 with 1 tasks resource profile 0
# 25/02/07 17:36:28 INFO TaskSetManager: Starting task 0.0 in stage 31.0 (TID 29) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4496 bytes) taskResourceAssignments Map()
# 25/02/07 17:36:28 INFO Executor: Running task 0.0 in stage 31.0 (TID 29)
# 25/02/07 17:36:28 INFO PythonRunner: Times: total = 80, boot = 4, init = 76, finish = 0
# 25/02/07 17:36:28 INFO Executor: Finished task 0.0 in stage 31.0 (TID 29). 4365 bytes result sent to driver
# 25/02/07 17:36:28 INFO TaskSetManager: Finished task 0.0 in stage 31.0 (TID 29) in 87 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Removed TaskSet 31.0, whose tasks have all completed, from pool
# 25/02/07 17:36:28 INFO DAGScheduler: ResultStage 31 (showString at <unknown>:0) finished in 0.093 s
# 25/02/07 17:36:28 INFO DAGScheduler: Job 29 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Killing all running tasks in stage 31: Stage finished
# 25/02/07 17:36:28 INFO DAGScheduler: Job 29 finished: showString at <unknown>:0, took 0.097185 s
# 25/02/07 17:36:28 INFO CodeGenerator: Code generated in 6.286299 ms
# 25/02/07 17:36:28 INFO SparkContext: Starting job: showString at <unknown>:0
# 25/02/07 17:36:28 INFO DAGScheduler: Got job 30 (showString at <unknown>:0) with 1 output partitions
# 25/02/07 17:36:28 INFO DAGScheduler: Final stage: ResultStage 32 (showString at <unknown>:0)
# 25/02/07 17:36:28 INFO DAGScheduler: Parents of final stage: List()
# 25/02/07 17:36:28 INFO DAGScheduler: Missing parents: List()
# 25/02/07 17:36:28 INFO DAGScheduler: Submitting ResultStage 32 (MapPartitionsRDD[190] at showString at <unknown>:0), which has no missing parents
# 25/02/07 17:36:28 INFO MemoryStore: Block broadcast_30 stored as values in memory (estimated size 14.7 KiB, free 6.2 GiB)
# 25/02/07 17:36:28 INFO MemoryStore: Block broadcast_30_piece0 stored as bytes in memory (estimated size 7.5 KiB, free 6.2 GiB)
# 25/02/07 17:36:28 INFO BlockManagerInfo: Added broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:28 INFO SparkContext: Created broadcast 30 from broadcast at DAGScheduler.scala:1570
# 25/02/07 17:36:28 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 32 (MapPartitionsRDD[190] at showString at <unknown>:0) (first 15 tasks are for partitions Vector(0))
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Adding task set 32.0 with 1 tasks resource profile 0
# 25/02/07 17:36:28 INFO TaskSetManager: Starting task 0.0 in stage 32.0 (TID 30) (1cdc7ec21abb, executor driver, partition 0, PROCESS_LOCAL, 4496 bytes) taskResourceAssignments Map()
# 25/02/07 17:36:28 INFO Executor: Running task 0.0 in stage 32.0 (TID 30)
# +-------+---+
# |   name|age|
# +-------+---+
# |  Alice| 30|
# |   Manu| 37|
# |Charlie| 51|
# +-------+---+
#
# +-------+---+
# |   name|age|
# +-------+---+
# |Charlie| 51|
# |   Manu| 37|
# |  Alice| 30|
# +-------+---+
# 25/02/07 17:36:28 INFO PythonRunner: Times: total = 62, boot = -74, init = 136, finish = 0
# 25/02/07 17:36:28 INFO Executor: Finished task 0.0 in stage 32.0 (TID 30). 4365 bytes result sent to driver
# 25/02/07 17:36:28 INFO TaskSetManager: Finished task 0.0 in stage 32.0 (TID 30) in 69 ms on 1cdc7ec21abb (executor driver) (1/1)
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Removed TaskSet 32.0, whose tasks have all completed, from pool
# 25/02/07 17:36:28 INFO DAGScheduler: ResultStage 32 (showString at <unknown>:0) finished in 0.075 s
# 25/02/07 17:36:28 INFO DAGScheduler: Job 30 is finished. Cancelling potential speculative or zombie tasks for this job
# 25/02/07 17:36:28 INFO TaskSchedulerImpl: Killing all running tasks in stage 32: Stage finished
# 25/02/07 17:36:28 INFO DAGScheduler: Job 30 finished: showString at <unknown>:0, took 0.078482 s
# 25/02/07 17:36:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:36:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:36:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:36:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:36:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:36:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:36:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:36:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:36:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:36:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:36:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:36:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:37:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:37:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:37:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:37:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:37:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:38:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:38:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:38:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:38:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:38:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:39:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:39:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:39:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:39:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:39:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:40:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:40:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:40:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:40:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:40:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:41:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:41:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:41:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:41:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:41:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:43 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:43 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:43 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:43 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:42:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:42:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:42:53 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:42:53 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:53 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:42:53 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:43:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:43:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:03 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:43:03 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:03 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:03 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:43:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:43:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:13 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:43:13 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:13 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:13 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:43:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:43:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:23 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:43:23 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:23 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:23 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:43:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:43:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:43:33 INFO BlockManager: Reporting 6 blocks to the master.
# 25/02/07 17:43:33 INFO BlockManagerInfo: Updated broadcast_28_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:33 INFO BlockManagerInfo: Updated broadcast_29_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:33 INFO BlockManagerInfo: Updated broadcast_30_piece0 in memory on 1cdc7ec21abb:36743 (current size: 7.5 KiB, original size: 7.5 KiB, free: 6.2 GiB)
# 25/02/07 17:43:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:43:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:43:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# ...
# 25/02/07 17:57:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:57:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:57:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:57:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:57:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:57:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:57:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:57:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:57:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:57:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:58:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:58:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:58:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:58:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 17:59:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 17:59:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 17:59:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 17:59:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:00:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:00:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:00:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:00:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:43 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:01:53 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:01:53 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:01:53 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:53 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:01:53 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:02:03 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:02:03 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:02:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:03 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:02:13 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:02:13 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:02:13 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:13 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:13 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:02:23 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:02:23 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:02:23 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:23 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:02:33 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:02:33 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:02:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:33 INFO BlockManager: Reporting 0 blocks to the master.
# 25/02/07 18:02:43 INFO Executor: Told to re-register on heartbeat
# 25/02/07 18:02:43 INFO BlockManager: BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None) re-registering with master
# 25/02/07 18:02:43 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:43 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 1cdc7ec21abb, 36743, None)
# 25/02/07 18:02:43 INFO BlockManager: Reporting 0 blocks to the master.
